# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import json
import collections

# %%
pop_data = "Resources\population_data.csv"
pop_data_df = pd.read_csv(pop_data)
pop_data_df.head(25)
# Out:
#            State      2010      2011      2012      2013      2014      2015  \
# 0     California  37320903  37641823  37960782  38280824  38625139  38953142
# 1          Texas  25242679  25646227  26089620  26489464  26977142  27486814
# 2        Florida  18845785  19093352  19326230  19563166  19860330  20224249
# 3       New York  19400080  19498514  19574549  19628043  19656330  19661411
# 4   Pennsylvania  12711158  12744583  12766827  12776621  12789101  12785759
# 5       Illinois  12840762  12867291  12884119  12898269  12888962  12864342
# 6           Ohio  11539327  11543463  11548369  11576576  11602973  11617850
# 7        Georgia   9711810   9801578   9901496   9973326  10069001  10181111
# 8        Wyoming    564483    567224    576270    582123    582548    585668
# 9        Vermont    625880    626979    626063    626212    625218    625197
# 10        Alaska    713906    722038    730399    737045    736307    737547
# ...

# %%
for state in pop_data_df["State"]:
    x_axis = pop_data_df.columns.tolist()
    y_axis = pop_data_df.loc[pop_data_df["State"]== state][2,:]
    plt.plot(x_axis, y_axis)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-dc365ce98bb0> in <module>
#       1 for state in pop_data_df["State"]:
#       2     x_axis = pop_data_df.columns.tolist()
# ----> 3     y_axis = pop_data_df.loc[pop_data_df["State"]== state][2,:]
#       4     plt.plot(x_axis, y_axis)
#       5     plt.show()
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 )
#    2896             try:
# ...
