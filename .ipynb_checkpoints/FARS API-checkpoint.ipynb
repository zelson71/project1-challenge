# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import json

# %%
url = "https://crashviewer.nhtsa.dot.gov/CrashAPI/crashes/GetCrashesByLocation?"
#fromCaseYear=2014&toCaseYear=2015&state=1&county=1&format=json
FromYear = "2008"
ToYear = "2015"
State = "48"
query_url = url + "fromCaseYear=" + FromYear + "&toCaseYear=" + ToYear + "&state=" + State + "&county=" + "&format=json"
response = requests.get(query_url).json()
#https://crashviewer.nhtsa.dot.gov/CrashAPI/crashes/GetCrashesByLocation?fromCaseYear=2014&toCaseYear2015&state=1&county=1&format=json
print(query_url)
#https://crashviewer.nhtsa.dot.gov/CrashAPI/crashes/GetCrashesByLocation?fromCaseYear=2014&toCaseYear=2015&state=1&county=1&format=json
# Out:
# https://crashviewer.nhtsa.dot.gov/CrashAPI/crashes/GetCrashesByLocation?fromCaseYear=2008&toCaseYear=2015&state=48&county=&format=json

# %%
state = []

for state in states:
    response = requests.get(query_url).json()
    try:
        state.append(weather_response['id'])
        name.append(weather_response['name'])
        print(f"{weather_response['id']}: {weather_response['name']}")
        lat.append(weather_response['coord']['lat'])
        lng.append(weather_response['coord']['lon'])
        temperature.append(weather_response['main']['temp'])
        humidity.append(weather_response['main']['humidity'])
        cloudiness.append(weather_response['clouds']['all'])
        wind_speed.append(weather_response['wind']['speed'])
        temp_max.append(weather_response['main']['temp_max'])
    except KeyError:
        pass

# %%
pprint(response)
# Out:
# {'Count': 17996,
#  'Message': 'Warning: Showing 5000 of 17996 records. Please use the same api '
#             'call and change your search paramerters or year range to get '
#             'complete record counts.',
#  'Results': [[{'CITY': '0',
#                'CITYNAME': 'NOT APPLICABLE',
#                'COUNTY': '89',
#                'COUNTYNAME': 'COLORADO (89)',
#                'CaseYear': '2010',
#                'FATALS': '1',
#                'LATITUDE': '29.75174167',
#                'LONGITUD': '-96.605141670',
#                'STATE': '48',
#                'STATENAME': 'Texas',
#                'ST_CASE': '480001',
#                'TOTALVEHICLES': '1',
#                'TWAY_ID': 'SR-71',
#                'TWAY_ID2': '',
#                'VE_FORMS': '1'},
#               {'CITY': '0',
#                'CITYNAME': 'NOT APPLICABLE',
#                'COUNTY': '37',
#                'COUNTYNAME': 'BOWIE (37)',
#                'CaseYear': '2015',
# ...
